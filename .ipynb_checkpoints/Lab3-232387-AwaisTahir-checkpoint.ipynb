# %% [markdown]
# # AWAIS TAHIR
# # 232387
# # BSCSev-V-B

# %% [markdown]
# ## Numeric Types

# %%
x = 1         
y = 8.8       
z = 3j        

print(type(x))  
print(type(y)) 
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ## Integer examples

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))  
print(type(y))  
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ## Float examples

# %%
x = 55.10
y = 8.0
z = -84.59

print(type(x))  
print(type(y))
# Out:
# <class 'float'>
# <class 'float'>

# %% [markdown]
# # Complex numbers

# %%
x = 3 + 5j
y = 5j


print(type(x))  
print(type(y))
# Out:
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# # Type conversion

# %%
x = 1       
y = 2.8     
z = 1j      

a = float(x)    
b = int(y)      
c = complex(x)  

print(a)           
print(b)
# Out:
# 1.0
# 2

# %% [markdown]
# # Quotes inside quotes

# %%
print("Hellow iam learning ai in this lab")
print("Myname is awais Tahir")
print('I once made a trading chatbot')
# Out:
# Hellow iam learning ai in this lab
# Myname is awais Tahir
# I once made a chatbot

# %% [markdown]
# # Calculate Average

# %%
num = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))


average = (num + num2 + num3) / 3

print("The average is:", average)
# Out:
# Enter first number:  45
# Enter second number:  54
# Enter third number:  66
# The average is: 55.0

# %% [markdown]
# # sIMple Calculator hardcoded values

# %%
num1 = 30
num2 = 10
operator = input("Enter operator +, -, *, /: ")

if operator == '+':
    result = num1 + num2
elif operator == '-':
    result = num1 - num2
elif operator == '*':
    result = num1 * num2
elif operator == '/':
    if num2 != 0:
        result = num1 / num2
else:
    result = "Invalid operator!"

print(f"{num1} {operator} {num2} = {result}")
# Out:
# Enter operator (+, -, *, /):  +
# 30 + 10 = 40

# %% [markdown]
# # Calculator With user values

# %%
num1 = float(input("Enter a number: "))
operator = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if operator == '+':
    result = num1 + num2
elif operator == '-':
    result = num1 - num2
elif operator == '*':
    result = num1 * num2
elif operator == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "can not didivided by zero."
else:
    result = "Invalid operator"

print("Result:", result)
# Out:
# Enter a number:  4
# Enter operator (+, -, *, /):  *
# Enter second number:  4
# Result: 16.0

# %% [markdown]
# # ATM MAchine

# %%
balance = float(input("Enter your balance"))

print("Welcome to the ATM!")
print("1. Check Balance")
print("2. Withdraw Money")
print("3. Deposit Money")

choice = input("Enter your choice (1/2/3): ")

if choice == '1':
    print(f"Your balance is: ${balance}")
elif choice == '2':
    amount = float(input("Enter amount to withdraw: "))
    if amount > balance:
        print("Insufficient balance!")
    else:
        balance -= amount
        print(f"Please take your cash: ${amount}")
        print(f"Remaining balance: ${balance}")
elif choice == '3':
    amount = float(input("Enter amount to deposit: "))
    balance += amount
    print(f"${amount} deposited successfully.")
    print(f"New balance: ${balance}")
else:
    print("Invalid choice!")
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/msys64/ucrt64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'
